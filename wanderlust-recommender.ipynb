# %%
import pandas as pd
# !pip install gcsfs -q

# %%
# Define the paths to your data in Google Cloud Storage
bucket_name = 'wanderlust-recommender-system'
file_path1 = f'gs://{bucket_name}/Datafiniti_Hotel_Reviews.csv'
file_path2 = f'gs://{bucket_name}/Datafiniti_Hotel_Reviews_Jun19.csv'

# Load each CSV file into its own pandas DataFrame
try:
    df1 = pd.read_csv(file_path1)
    df2 = pd.read_csv(file_path2)
    print("Successfully loaded both CSV files.")
except Exception as e:
    print(f"Error loading files: {e}")

# Combine the two DataFrames into one
combined_df = pd.concat([df1, df2], ignore_index=True)

print(f"\nSuccessfully combined the datasets.")
print(f"Original size of df1: {len(df1)} rows")
print(f"Original size of df2: {len(df2)} rows")
print(f"Size of combined dataset: {len(combined_df)} rows")

# --- Cleaning & Preprocessing ---

# Define the columns that are essential for reviews
required_columns = ['reviews.text', 'reviews.rating', 'name', 'reviews.username']

# Drop rows that are missing any of these critical values.
initial_rows = len(combined_df)
combined_df.dropna(subset=required_columns, inplace=True)
print(f"\nDropped {initial_rows - len(combined_df)} rows with missing required values.")

# Check for and remove duplicate reviews
initial_rows = len(combined_df)
combined_df.drop_duplicates(subset=['reviews.text', 'reviews.username'], inplace=True)
print(f"Dropped {initial_rows - len(combined_df)} duplicate reviews.")


# --- Creating Numerical IDs ---
combined_df['hotel_id'] = pd.factorize(combined_df['name'])[0]
combined_df['user_id'] = pd.factorize(combined_df['reviews.username'])[0]


# --- Final Verification ---

print("\n--- Final Cleaned DataFrame ---")
combined_df.info()
combined_df.head(20)
# Out:
# Successfully loaded both CSV files.
#
# Successfully combined the datasets.
# Original size of df1: 10000 rows
# Original size of df2: 10000 rows
# Size of combined dataset: 20000 rows
#
# Dropped 1 rows with missing required values.
# Dropped 306 duplicate reviews.
#
# --- Final Cleaned DataFrame ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 19693 entries, 0 to 19999
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    19693 non-null  object
#  1   dateAdded             19693 non-null  object
#  2   dateUpdated           19693 non-null  object
#  3   address               19693 non-null  object
#  4   categories            19693 non-null  object
#  5   primaryCategories     19693 non-null  object
#  6   city                  19693 non-null  object
#  7   country               19693 non-null  object
#  8   keys                  19693 non-null  object
#  9   latitude              19693 non-null  float64
#  10  longitude             19693 non-null  float64
#  11  name                  19693 non-null  object
#  12  postalCode            19693 non-null  object
#  13  province              19693 non-null  object
#  14  reviews.date          19693 non-null  object
#  15  reviews.dateSeen      19693 non-null  object
#  16  reviews.rating        19693 non-null  float64
#  17  reviews.sourceURLs    19693 non-null  object
#  18  reviews.text          19693 non-null  object
#  19  reviews.title         19691 non-null  object
#  20  reviews.userCity      13862 non-null  object
#  21  reviews.userProvince  12401 non-null  object
#  22  reviews.username      19693 non-null  object
#  23  sourceURLs            19693 non-null  object
#  24  websites              19693 non-null  object
#  25  reviews.dateAdded     0 non-null      float64
#  26  hotel_id              19693 non-null  int64
# 8      7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
# 9   315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 10  315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 11  315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 12  315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 13  315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 14  315 SE Olympia Dr  Hotels,Hotels and motels,Hotel and motel reser...
# 15      106 W 12th St  Hotels,Caterers,Hotels and motels,Hotel,Restau...
# 16      106 W 12th St  Hotels,Caterers,Hotels and motels,Hotel,Restau...
# 17      106 W 12th St  Hotels,Caterers,Hotels and motels,Hotel,Restau...
# 18      106 W 12th St  Hotels,Caterers,Hotels and motels,Hotel,Restau...
# 19      106 W 12th St  Hotels,Caterers,Hotels and motels,Hotel,Restau...
#
#                 primaryCategories             city country  \
# 0   Accommodation & Food Services  Rancho Santa Fe      US
# 1   Accommodation & Food Services  Rancho Santa Fe      US
# 2   Accommodation & Food Services  Rancho Santa Fe      US
# 3   Accommodation & Food Services          Hanover      US
# 4   Accommodation & Food Services          Hanover      US
# 5   Accommodation & Food Services          Hanover      US
# 6   Accommodation & Food Services          Hanover      US
# 7   Accommodation & Food Services          Hanover      US
# 8   Accommodation & Food Services          Hanover      US
# 9   Accommodation & Food Services        Vancouver      US
# 10  Accommodation & Food Services        Vancouver      US
# 11  Accommodation & Food Services        Vancouver      US
# 12  Accommodation & Food Services        Vancouver      US
# 13  Accommodation & Food Services        Vancouver      US
# 14  Accommodation & Food Services        Vancouver      US
# 15  Accommodation & Food Services      Kansas City      US
# 16  Accommodation & Food Services      Kansas City      US
# 17  Accommodation & Food Services      Kansas City      US
# 18  Accommodation & Food Services      Kansas City      US
# 19  Accommodation & Food Services      Kansas City      US
#
#                                              keys   latitude  ...  \
# 0   us/ca/ranchosantafe/5921valenciacir/359754519  32.990959  ...
# 1   us/ca/ranchosantafe/5921valenciacir/359754519  32.990959  ...
# 2   us/ca/ranchosantafe/5921valenciacir/359754519  32.990959  ...
# 3          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 4          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 5          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 6          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 7          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 8          us/md/hanover/7520teaguerd/-2043779672  39.155929  ...
# 9       us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 10      us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 11      us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 12      us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 13      us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 14      us/wa/vancouver/315seolympiadr/1818657156  45.619212  ...
# 15         us/mo/kansascity/106w12thst/1243084175  39.100119  ...
# 16         us/mo/kansascity/106w12thst/1243084175  39.100119  ...
# 17         us/mo/kansascity/106w12thst/1243084175  39.100119  ...
# 18         us/mo/kansascity/106w12thst/1243084175  39.100119  ...
# 19         us/mo/kansascity/106w12thst/1243084175  39.100119  ...
#
#                                          reviews.text  \
# 0   Our experience at Rancho Valencia was absolute...
# 1   Amazing place. Everyone was extremely warm and...
# 2   We booked a 3 night stay at Rancho Valencia to...
# 3   Currently in bed writing this for the past hr ...
# 4   I live in Md and the Aloft is my Home away fro...
# 5   I stayed here with my family for my daughters ...
# 6   Beautiful rooms and the nicest people working ...
# 7   We stayed here while visiting Maryland Live!. ...
# 8   I travel a lot with my job, so I'm constantly ...
# 9   In my line of work, I use meeting space in hot...
# 10  The staff is very friendly and helpful. The ro...
# 11  Very friendly staff, great free breakfast item...
# 12  Upon arriving I see modern yet elegant decor w...
# 13  This is a nice hotel with great staff. I have ...
# 14  Beautiful property and every staff member I en...
# 15  Old hotel with many remaining architectural ch...
# 16  Very comfortable room. Our son came and they h...
# 17  Stayed here for second time recently. Gorgeous...
# 18  My husband and I always try to stay at the Hot...
# 19  Just stayed one night but very happy. Nice, co...
#
#                                     reviews.title reviews.userCity  \
# 0                 Best romantic vacation ever!!!!              NaN
# 1                            Sweet sweet serenity              NaN
# 2                 Amazing Property and Experience              NaN
# 3        Never again...beware, if you want sleep.         Richmond
# 4                            ALWAYS GREAT STAY...           Laurel
# 5                                  Wonderful stay           Laurel
# 6                                 Worth the money              NaN
# 7                          Great Hotel Experiece!          Clayton
# 8                        Short stay for business.           Boston
# 9                Amazing employees and facilities         Portland
# 10                          I loved our stay here              NaN
# 11                     Hampton Inn - Vancouver WA          Antioch
# 12                                     Perfection         Portland
# 13                Good hotel. Worth checking out.     Port Orchard
# 14                                     Excellent!        San Diego
# 15                                   Very pleased              NaN
# 16                                 Excellent Stay              NaN
# 17            Beautiful lobby but rooms need help              NaN
# 18  Hotel's 1920s charm and elegance remain fresh          Wichita
# 19                                 Excellent stay          Chicago
#
#    reviews.userProvince      reviews.username  \
# 0                   NaN                 Paula
# 1                   NaN                     D
# 2                   NaN                   Ron
# 3                    VA             jaeem2016
# 4                    MD            MamaNiaOne
# 5                    MD              kevan777
# 6                   NaN            Princess F
# 7                    NC           DebMurphy57
# 8                    MA  kayleighwillswim1224
# 9                   NaN              KristyWM
# 10                  NaN                   B M
# 11                  NaN            Cathleen S
# 12                  NaN               1fiesty
# 13                   WA         810michellemm
# 14                   CA       travelchick1113
# 15                  NaN           AimlessinMe
# 16                  NaN             Tabitha K
# 17                  NaN            Yamachaser
# 18                   KS           Rbuffington
# 19                   IL                Nick F
#
#                                            sourceURLs  \
# 0   http://www.hotels.com/ho125419/%25252525253Flo...
# 1   http://www.hotels.com/ho125419/%25252525253Flo...
# 2   http://www.hotels.com/ho125419/%25252525253Flo...
# 3   http://www.yellowbook.com/profile/aloft-arunde...
# 4   http://www.yellowbook.com/profile/aloft-arunde...
# 5   http://www.yellowbook.com/profile/aloft-arunde...
# 6   http://www.yellowbook.com/profile/aloft-arunde...
# 7   http://www.yellowbook.com/profile/aloft-arunde...
# 8   http://www.yellowbook.com/profile/aloft-arunde...
# 9   https://www.yellowpages.com/vancouver-wa/mip/h...
# 10  https://www.yellowpages.com/vancouver-wa/mip/h...
# 11  https://www.yellowpages.com/vancouver-wa/mip/h...
# 12  https://www.yellowpages.com/vancouver-wa/mip/h...
# 13  https://www.yellowpages.com/vancouver-wa/mip/h...
# 14  https://www.yellowpages.com/vancouver-wa/mip/h...
# 15  http://www.gayot.com/Hotels/Select-Your-City/U...
# 16  http://www.gayot.com/Hotels/Select-Your-City/U...
# 17  http://www.gayot.com/Hotels/Select-Your-City/U...
# 18  http://www.gayot.com/Hotels/Select-Your-City/U...
# 19  http://www.gayot.com/Hotels/Select-Your-City/U...
#
#                                              websites reviews.dateAdded  \
# 0                       http://www.ranchovalencia.com               NaN
# 1                       http://www.ranchovalencia.com               NaN
# 2                       http://www.ranchovalencia.com               NaN
# 3   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 4   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 5   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 6   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 7   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 8   http://www.starwoodhotels.com/alofthotels/prop...               NaN
# 9   http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 10  http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 11  http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 12  http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 13  http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 14  http://hamptoninn3.hilton.com/en/hotels/washin...               NaN
# 15  http://curiocollection3.hilton.com/en/hotels/m...               NaN
# 16  http://curiocollection3.hilton.com/en/hotels/m...               NaN
# 17  http://curiocollection3.hilton.com/en/hotels/m...               NaN
# 18  http://curiocollection3.hilton.com/en/hotels/m...               NaN
# 19  http://curiocollection3.hilton.com/en/hotels/m...               NaN
#
#    hotel_id user_id
# 0         0       0
# 1         0       1
# 2         0       2
# 3         1       3
# 4         1       4
# 5         1       5
# 6         1       6
# 7         1       7
# 8         1       8
# 9         2       9
# 10        2      10
# 11        2      11
# 12        2      12
# 13        2      13
# 14        2      14
# 15        3      15
# 16        3      16
# 17        3      17
# 18        3      18
# 19        3      19
#
# [20 rows x 28 columns]
